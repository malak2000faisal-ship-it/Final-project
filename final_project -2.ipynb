# %%
# !pip install tensorflow opencv-python numpy pillow scikit-learn openpyxl
# Out:
# Requirement already satisfied: tensorflow in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (2.21.0)
# Requirement already satisfied: opencv-python in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (4.13.0.90)
# Requirement already satisfied: numpy in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (2.3.3)
# Requirement already satisfied: pillow in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (12.0.0)
# Requirement already satisfied: scikit-learn in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (1.8.0)
# Requirement already satisfied: openpyxl in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (3.1.5)
# Requirement already satisfied: absl-py>=1.0.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (6.33.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in C:\Users\con027931\AppData\Roaming\Python\Python313\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: keras>=3.12.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (3.13.1)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: et-xmlfile in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from keras>=3.12.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)

# %%
import os, random, json, csv
import numpy as np
import cv2
from PIL import Image
from datetime import datetime
import openpyxl

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder

# %%
STUDENTS_FOLDER = 'Faces'
IMG_SIZE        = (128, 128)
SEED            = 42

random.seed(SEED)
np.random.seed(SEED)
tf.keras.utils.set_random_seed(SEED)

# %%
def load_img(path):
    img = Image.open(path).convert('RGB').resize(IMG_SIZE)
    return np.array(img).astype(np.float32) / 255.0

X      = []
labels = []

for filename in os.listdir(STUDENTS_FOLDER):
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        path = os.path.join(STUDENTS_FOLDER, filename)
        name = os.path.splitext(filename)[0]
        name = '_'.join(name.split('_')[:-1])
        X.append(load_img(path))
        labels.append(name)

X = np.array(X)
print('Dataset shape:', X.shape)
print('Unique students:', set(labels))
# Out:
# Dataset shape: (2377, 128, 128, 3)
# Unique students: {'Anushka Sharma', 'Hugh Jackman', 'Billie Eilish', 'Marmik', 'Roger Federer', 'Jessica Alba', 'Tom Cruise', 'Margot Robbie', 'Zac Efron', 'Elizabeth Olsen', 'Courtney Cox', 'Dwayne Johnson', 'Priyanka Chopra', 'Charlize Theron', 'Alia Bhatt', 'Vijay Deverakonda', 'Camila Cabello', 'Lisa Kudrow', 'Henry Cavill', 'Robert Downey Jr', 'Natalie Portman', 'Hrithik Roshan', 'Kashyap', 'Virat Kohli', 'Ellen Degeneres', 'Andy Samberg', 'Brad Pitt', 'Amitabh Bachchan', 'Claire Holt'}

# %%
le      = LabelEncoder()
y       = le.fit_transform(labels)
n_class = len(le.classes_)

print('Number of students:', n_class)
print('Classes:', le.classes_)
# Out:
# Number of students: 29
# Classes: ['Alia Bhatt' 'Amitabh Bachchan' 'Andy Samberg' 'Anushka Sharma'
#  'Billie Eilish' 'Brad Pitt' 'Camila Cabello' 'Charlize Theron'
#  'Claire Holt' 'Courtney Cox' 'Dwayne Johnson' 'Elizabeth Olsen'
#  'Ellen Degeneres' 'Henry Cavill' 'Hrithik Roshan' 'Hugh Jackman'
#  'Jessica Alba' 'Kashyap' 'Lisa Kudrow' 'Margot Robbie' 'Marmik'
#  'Natalie Portman' 'Priyanka Chopra' 'Robert Downey Jr' 'Roger Federer'
#  'Tom Cruise' 'Vijay Deverakonda' 'Virat Kohli' 'Zac Efron']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.15, random_state=SEED
)

X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.15, random_state=SEED
)

print('Train:', len(X_train))
print('Val  :', len(X_val))
print('Test :', len(X_test))
# Out:
# Train: 1717
# Val  : 303
# Test : 357

# %%
inp = Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
print('Input shape    :', inp.shape)

x = Conv2D(32, 3, activation='relu', padding='same')(inp)
print('After Conv2D(32)  :', x.shape)

x = MaxPooling2D()(x)
print('After MaxPooling  :', x.shape)

x = Conv2D(64, 3, activation='relu', padding='same')(x)
print('After Conv2D(64)  :', x.shape)

x = MaxPooling2D()(x)
print('After MaxPooling  :', x.shape)

x = Conv2D(128, 3, activation='relu', padding='same')(x)
print('After Conv2D(128) :', x.shape)

x = MaxPooling2D()(x)
print('After MaxPooling  :', x.shape)

x = Flatten()(x)
print('After Flatten     :', x.shape)

# Dropout يشتغل بس أثناء التدريب ويطفي نفسه تلقائياً وقت التطبيق
x = Dropout(0.3)(x)

x   = Dense(128, activation='relu')(x)
print('After Dense(128)  :', x.shape)

out = Dense(n_class, activation='softmax')(x)
print('Output shape      :', out.shape)
# Out:
# Input shape    : (None, 128, 128, 3)
# After Conv2D(32)  : (None, 128, 128, 32)
# After MaxPooling  : (None, 64, 64, 32)
# After Conv2D(64)  : (None, 64, 64, 64)
# After MaxPooling  : (None, 32, 32, 64)
# After Conv2D(128) : (None, 32, 32, 128)
# After MaxPooling  : (None, 16, 16, 128)
# After Flatten     : (None, 32768)
# After Dense(128)  : (None, 128)
# Output shape      : (None, 29)

# %%
model = Model(inp, out)
model.compile(
    optimizer = 'adam',
    loss      = 'sparse_categorical_crossentropy',
    metrics   = ['accuracy']
)

model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     4,194,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 29)             │         3,741 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,291,421 (16.37 MB)
#  Trainable params: 4,291,421 (16.37 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train, y_train,
    epochs          = 50,
    batch_size      = 8,
    validation_data = (X_val, y_val)
)
# Out:
# Epoch 1/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - accuracy: 0.0751 - loss: 3.2826 - val_accuracy: 0.0990 - val_loss: 3.1328
# Epoch 2/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - accuracy: 0.3023 - loss: 2.4082 - val_accuracy: 0.3729 - val_loss: 2.2359
# Epoch 3/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 12s 57ms/step - accuracy: 0.5457 - loss: 1.5215 - val_accuracy: 0.5380 - val_loss: 1.6734
# Epoch 4/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - accuracy: 0.7169 - loss: 0.9318 - val_accuracy: 0.5842 - val_loss: 1.6253
# Epoch 5/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 64ms/step - accuracy: 0.7985 - loss: 0.6062 - val_accuracy: 0.5743 - val_loss: 1.7966
# Epoch 6/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - accuracy: 0.8818 - loss: 0.3466 - val_accuracy: 0.5908 - val_loss: 2.0897
# Epoch 7/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.9249 - loss: 0.2300 - val_accuracy: 0.5677 - val_loss: 2.4366
# Epoch 8/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 64ms/step - accuracy: 0.9377 - loss: 0.1928 - val_accuracy: 0.6172 - val_loss: 2.1369
# Epoch 9/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - accuracy: 0.9435 - loss: 0.1848 - val_accuracy: 0.5743 - val_loss: 2.3720
# Epoch 10/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 64ms/step - accuracy: 0.9755 - loss: 0.0894 - val_accuracy: 0.6304 - val_loss: 2.0982
# Epoch 11/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 63ms/step - accuracy: 0.9755 - loss: 0.0773 - val_accuracy: 0.6040 - val_loss: 2.5477
# Epoch 12/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - accuracy: 0.9604 - loss: 0.1176 - val_accuracy: 0.6106 - val_loss: 2.5592
# Epoch 13/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 64ms/step - accuracy: 0.9621 - loss: 0.1225 - val_accuracy: 0.6040 - val_loss: 2.5576
# Epoch 14/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - accuracy: 0.9744 - loss: 0.0901 - val_accuracy: 0.5941 - val_loss: 2.5705
# Epoch 15/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - accuracy: 0.9872 - loss: 0.0408 - val_accuracy: 0.5941 - val_loss: 2.6597
# Epoch 16/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 64ms/step - accuracy: 0.9837 - loss: 0.0626 - val_accuracy: 0.6271 - val_loss: 2.6210
# Epoch 17/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.9750 - loss: 0.0900 - val_accuracy: 0.6238 - val_loss: 2.5909
# Epoch 18/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - accuracy: 0.9854 - loss: 0.0471 - val_accuracy: 0.6205 - val_loss: 2.5464
# Epoch 19/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - accuracy: 0.9814 - loss: 0.0613 - val_accuracy: 0.5611 - val_loss: 3.6304
# Epoch 20/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 15s 70ms/step - accuracy: 0.9709 - loss: 0.0919 - val_accuracy: 0.6172 - val_loss: 2.7221
# Epoch 21/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 64ms/step - accuracy: 0.9884 - loss: 0.0456 - val_accuracy: 0.6304 - val_loss: 2.6992
# Epoch 22/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 64ms/step - accuracy: 0.9895 - loss: 0.0286 - val_accuracy: 0.6865 - val_loss: 2.8824
# Epoch 23/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - accuracy: 0.9971 - loss: 0.0101 - val_accuracy: 0.6601 - val_loss: 2.7522
# Epoch 24/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.9755 - loss: 0.0759 - val_accuracy: 0.6106 - val_loss: 3.1684
# Epoch 25/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - accuracy: 0.9750 - loss: 0.0780 - val_accuracy: 0.6337 - val_loss: 3.1245
# Epoch 26/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.9907 - loss: 0.0334 - val_accuracy: 0.5908 - val_loss: 3.9489
# Epoch 27/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.9767 - loss: 0.0607 - val_accuracy: 0.6271 - val_loss: 3.0581
# Epoch 28/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - accuracy: 0.9901 - loss: 0.0316 - val_accuracy: 0.6436 - val_loss: 2.9846
# Epoch 29/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - accuracy: 0.9796 - loss: 0.0617 - val_accuracy: 0.6007 - val_loss: 3.7826
# Epoch 30/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - accuracy: 0.9825 - loss: 0.0457 - val_accuracy: 0.6304 - val_loss: 3.2898
# Epoch 31/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - accuracy: 0.9889 - loss: 0.0356 - val_accuracy: 0.6073 - val_loss: 4.4975
# Epoch 32/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.9796 - loss: 0.0573 - val_accuracy: 0.6337 - val_loss: 3.3231
# Epoch 33/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 15s 68ms/step - accuracy: 0.9814 - loss: 0.0576 - val_accuracy: 0.6106 - val_loss: 3.4734
# Epoch 34/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 15s 71ms/step - accuracy: 0.9930 - loss: 0.0333 - val_accuracy: 0.6271 - val_loss: 3.8355
# Epoch 35/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 20s 94ms/step - accuracy: 0.9738 - loss: 0.0964 - val_accuracy: 0.6370 - val_loss: 2.7795
# Epoch 36/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 21s 97ms/step - accuracy: 0.9942 - loss: 0.0186 - val_accuracy: 0.5941 - val_loss: 3.4743
# Epoch 37/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 17s 80ms/step - accuracy: 0.9767 - loss: 0.0765 - val_accuracy: 0.6139 - val_loss: 3.6987
# Epoch 38/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 15s 70ms/step - accuracy: 0.9930 - loss: 0.0201 - val_accuracy: 0.5776 - val_loss: 3.9753
# Epoch 39/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 15s 71ms/step - accuracy: 0.9907 - loss: 0.0225 - val_accuracy: 0.6502 - val_loss: 3.3359
# Epoch 40/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 17s 81ms/step - accuracy: 0.9901 - loss: 0.0326 - val_accuracy: 0.6304 - val_loss: 3.6407
# Epoch 41/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 22s 103ms/step - accuracy: 0.9814 - loss: 0.0686 - val_accuracy: 0.5842 - val_loss: 3.9772
# Epoch 42/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 24s 109ms/step - accuracy: 0.9854 - loss: 0.0459 - val_accuracy: 0.6172 - val_loss: 3.7488
# Epoch 43/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 23s 106ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.6502 - val_loss: 3.5746
# Epoch 44/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 21s 98ms/step - accuracy: 1.0000 - loss: 6.0357e-04 - val_accuracy: 0.6502 - val_loss: 3.7140
# Epoch 45/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 20s 92ms/step - accuracy: 0.9802 - loss: 0.0559 - val_accuracy: 0.6007 - val_loss: 3.4782
# Epoch 46/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 17s 80ms/step - accuracy: 0.9773 - loss: 0.0727 - val_accuracy: 0.5776 - val_loss: 3.8455
# Epoch 47/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 16s 77ms/step - accuracy: 0.9901 - loss: 0.0410 - val_accuracy: 0.6304 - val_loss: 3.5800
# Epoch 48/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 20s 92ms/step - accuracy: 0.9913 - loss: 0.0233 - val_accuracy: 0.6370 - val_loss: 3.4710
# Epoch 49/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 15s 70ms/step - accuracy: 0.9918 - loss: 0.0231 - val_accuracy: 0.6634 - val_loss: 3.2058
# Epoch 50/50
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 15s 69ms/step - accuracy: 0.9918 - loss: 0.0210 - val_accuracy: 0.6205 - val_loss: 3.5508

# %%
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print('Test accuracy:', acc)

y_pred = np.argmax(model.predict(X_test), axis=1)
print('\nReport:\n', classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# Test accuracy: 0.605042040348053
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step
#
# Report:
#                     precision    recall  f1-score   support
#
#        Alia Bhatt       0.50      0.50      0.50         2
#  Amitabh Bachchan       1.00      0.79      0.88        14
#      Andy Samberg       0.83      0.50      0.62        10
#    Anushka Sharma       0.47      0.60      0.53        15
#     Billie Eilish       0.44      0.57      0.50        14
#         Brad Pitt       0.75      0.55      0.63        22
#    Camila Cabello       0.88      0.58      0.70        12
#   Charlize Theron       0.81      0.65      0.72        20
#       Claire Holt       1.00      0.38      0.55         8
#      Courtney Cox       0.33      0.57      0.42         7
#    Dwayne Johnson       0.75      0.30      0.43        10
#   Elizabeth Olsen       1.00      0.57      0.73         7
#   Ellen Degeneres       0.62      0.50      0.56        10
#      Henry Cavill       0.40      0.35      0.38        17
#    Hrithik Roshan       1.00      0.44      0.61        16
#      Hugh Jackman       0.75      0.67      0.71        18
#      Jessica Alba       0.39      0.64      0.49        14
#           Kashyap       0.67      0.33      0.44         6
#       Lisa Kudrow       0.62      0.77      0.69        13
#     Margot Robbie       0.56      0.56      0.56         9
#            Marmik       0.00      0.00      0.00         4
#   Natalie Portman       0.40      0.77      0.53        22
#   Priyanka Chopra       0.67      0.71      0.69        14
#  Robert Downey Jr       0.48      0.62      0.54        16
#     Roger Federer       0.86      0.75      0.80        16
#        Tom Cruise       0.29      0.57      0.38         7
# Vijay Deverakonda       0.70      0.94      0.80        17
#       Virat Kohli       0.75      0.50      0.60         6
#         Zac Efron       1.00      0.73      0.84        11
#
#          accuracy                           0.61       357
#         macro avg       0.65      0.57      0.58       357
#      weighted avg       0.67      0.61      0.61       357
# c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
# نحفظ أسماء الطلاب عشان نستخدمها في الكاميرا
# نقرأ أسماء الطلاب من الـ folder مباشرة
class_names = []
for filename in os.listdir(STUDENTS_FOLDER):
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        name = os.path.splitext(filename)[0]
        name = '_'.join(name.split('_')[:-1])
        if name not in class_names:
            class_names.append(name)

print('Students:', class_names)
class_names = list(le.classes_)
print('Students:', class_names)
# Out:
# Students: ['Alia Bhatt', 'Amitabh Bachchan', 'Andy Samberg', 'Anushka Sharma', 'Billie Eilish', 'Brad Pitt', 'Camila Cabello', 'Charlize Theron', 'Claire Holt', 'Courtney Cox', 'Dwayne Johnson', 'Elizabeth Olsen', 'Ellen Degeneres', 'Henry Cavill', 'Hrithik Roshan', 'Hugh Jackman', 'Jessica Alba', 'Kashyap', 'Lisa Kudrow', 'Margot Robbie', 'Marmik', 'Natalie Portman', 'Priyanka Chopra', 'Robert Downey Jr', 'Roger Federer', 'Tom Cruise', 'Vijay Deverakonda', 'Virat Kohli', 'Zac Efron']
# Students: [np.str_('Alia Bhatt'), np.str_('Amitabh Bachchan'), np.str_('Andy Samberg'), np.str_('Anushka Sharma'), np.str_('Billie Eilish'), np.str_('Brad Pitt'), np.str_('Camila Cabello'), np.str_('Charlize Theron'), np.str_('Claire Holt'), np.str_('Courtney Cox'), np.str_('Dwayne Johnson'), np.str_('Elizabeth Olsen'), np.str_('Ellen Degeneres'), np.str_('Henry Cavill'), np.str_('Hrithik Roshan'), np.str_('Hugh Jackman'), np.str_('Jessica Alba'), np.str_('Kashyap'), np.str_('Lisa Kudrow'), np.str_('Margot Robbie'), np.str_('Marmik'), np.str_('Natalie Portman'), np.str_('Priyanka Chopra'), np.str_('Robert Downey Jr'), np.str_('Roger Federer'), np.str_('Tom Cruise'), np.str_('Vijay Deverakonda'), np.str_('Virat Kohli'), np.str_('Zac Efron')]

# %%
# identify_face: تستخدم الـ model اللي بنيناه - مو model جاهز
# الـ Dropout يطفي نفسه تلقائياً هنا لأننا في وضع التطبيق مو التدريب
def identify_face(frame):
    img = Image.fromarray(frame).convert('RGB').resize(IMG_SIZE)
    img = np.array(img).astype(np.float32) / 255.0
    img = np.expand_dims(img, axis=0)

    pred       = model.predict(img, verbose=0)
    confidence = np.max(pred)
    class_idx  = np.argmax(pred)

    if confidence < 0.8:
        return None

    return class_names[class_idx]

# %%
def mark_attendance(name, status, csv_file='attendance.csv'):
    now      = datetime.now()
    date_str = now.strftime('%Y-%m-%d')
    time_str = now.strftime('%H:%M:%S') if status != 'Absent' else '---'

    if os.path.exists(csv_file):
        with open(csv_file, 'r', encoding='utf-8-sig') as f:
            reader = csv.DictReader(f)
            for row in reader:
                if row.get('Name') == name and row.get('Date') == date_str:
                    return False

    file_exists = os.path.exists(csv_file)
    with open(csv_file, 'a', newline='', encoding='utf-8-sig') as f:
        fieldnames = ['Name', 'Date', 'Arrival_Time', 'Status']
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        if not file_exists:
            writer.writeheader()
        writer.writerow({
            'Name'        : name,
            'Date'        : date_str,
            'Arrival_Time': time_str,
            'Status'      : status
        })
    return True

# %%
LATE_HOUR   = 8
LATE_MINUTE = 15

cap    = cv2.VideoCapture(0)
count  = 0
logged = {}

while True:
    success, frame = cap.read()
    if not success:
        break

    count += 1

    if count % 30 == 0:
        name = identify_face(frame)

        if name and name not in logged:
            now = datetime.now()
            if now.hour < LATE_HOUR or (now.hour == LATE_HOUR and now.minute < LATE_MINUTE):
                status = 'Present'
            else:
                status = 'Late'

            mark_attendance(name, status)
            logged[name] = status
            print(name)
            print(status)

    now_str = datetime.now().strftime('%H:%M:%S')
    cv2.putText(frame, f'Time: {now_str}', (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
    cv2.putText(frame, f'Present: {len(logged)}/{len(class_names)}', (10, 60),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

    y = 100
    for n, s in logged.items():
        color = (0, 255, 0) if s == 'Present' else (0, 165, 255)
        cv2.putText(frame, f'{n}: {s}', (10, y),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)
        y += 25

    cv2.imshow('Attendance System', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Zac Efron
# Late

# %%
for name in class_names:
    if name in logged:
        print(name, '|', logged[name])
    else:
        print(name, '| Absent')
        mark_attendance(name, 'Absent')

print('='*40)
print('Present :', sum(1 for v in logged.values() if v == 'Present'))
print('Late    :', sum(1 for v in logged.values() if v == 'Late'))
print('Absent  :', len([n for n in class_names if n not in logged]))
print('='*40)
# Out:
# Alia Bhatt | Absent
# Amitabh Bachchan | Absent
# Andy Samberg | Absent
# Anushka Sharma | Absent
# Billie Eilish | Absent
# Brad Pitt | Absent
# Camila Cabello | Absent
# Charlize Theron | Absent
# Claire Holt | Absent
# Courtney Cox | Absent
# Dwayne Johnson | Absent
# Elizabeth Olsen | Absent
# Ellen Degeneres | Absent
# Henry Cavill | Absent
# Hrithik Roshan | Absent
# Hugh Jackman | Absent
# Jessica Alba | Absent
# Kashyap | Absent
# Lisa Kudrow | Absent
# Margot Robbie | Absent
# Marmik | Absent
# Natalie Portman | Absent
# Priyanka Chopra | Absent
# Robert Downey Jr | Absent
# Roger Federer | Absent
# Tom Cruise | Absent
# Vijay Deverakonda | Absent
# Virat Kohli | Late
# Zac Efron | Absent
# ========================================
# Present : 0
# Late    : 1
# Absent  : 28
# ========================================

# %%
def save_to_excel(class_names, logged, filename='attendance.xlsx'):
    wb = openpyxl.Workbook()
    ws = wb.active
    ws.title = 'Attendance'
    ws.append(['Name', 'Date', 'Arrival Time', 'Status'])

    date_str = datetime.now().strftime('%Y-%m-%d')

    for name in class_names:
        status  = logged.get(name, 'Absent')
        arrival = '---'

        if os.path.exists('attendance.csv'):
            with open('attendance.csv', 'r', encoding='utf-8-sig') as f:
                reader = csv.DictReader(f)
                for row in reader:
                    if row.get('Name') == name and row.get('Date') == date_str:
                        arrival = row.get('Arrival_Time', '---')
                        break

        ws.append([name, date_str, arrival, status])

    wb.save(filename)
    print('saved to', filename)

save_to_excel(class_names, logged)
# Out:
# saved to attendance.xlsx
