# %%
# !pip install tensorflow opencv-python numpy pillow scikit-learn openpyxl
# Out:
# Requirement already satisfied: tensorflow in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (2.21.0)
# Requirement already satisfied: opencv-python in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (4.13.0.90)
# Requirement already satisfied: numpy in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (2.3.3)
# Requirement already satisfied: pillow in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (12.0.0)
# Requirement already satisfied: scikit-learn in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (1.8.0)
# Requirement already satisfied: openpyxl in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (3.1.5)
# Requirement already satisfied: absl-py>=1.0.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (6.33.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in C:\Users\con027931\AppData\Roaming\Python\Python313\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: keras>=3.12.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (3.13.1)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: et-xmlfile in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from keras>=3.12.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)

# %%
import os, random, json, csv
import numpy as np
import cv2
from PIL import Image
from datetime import datetime
import openpyxl

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics.pairwise import cosine_similarity

# %%
STUDENTS_FOLDER = 'Faces'
IMG_SIZE        = (128, 128)
SEED            = 42

random.seed(SEED)
np.random.seed(SEED)
tf.keras.utils.set_random_seed(SEED)

# %%
def load_img(path):
    img = Image.open(path).convert('RGB').resize(IMG_SIZE)
    return np.array(img).astype(np.float32) / 255.0

X      = []
labels = []

for filename in os.listdir(STUDENTS_FOLDER):
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        path = os.path.join(STUDENTS_FOLDER, filename)
        name = os.path.splitext(filename)[0]
        name = '_'.join(name.split('_')[:-1])
        X.append(load_img(path))
        labels.append(name)

X = np.array(X)
print('Dataset shape:', X.shape)
# Out:
# Dataset shape: (2377, 128, 128, 3)

# %%
print('Unique students:', set(labels))

# %%
le      = LabelEncoder()
y       = le.fit_transform(labels)
n_class = len(le.classes_)

print('Number of students:', n_class)
# Out:
# Number of students: 29

# %%
print('X shape:', X.shape)
print('y shape:', y.shape)
# Out:
# X shape: (14262, 128, 128, 3)
# y shape: (2377,)

# %%
le.classes_
# Out:
# array(['Alia Bhatt', 'Amitabh Bachchan', 'Andy Samberg', 'Anushka Sharma',
#        'Billie Eilish', 'Brad Pitt', 'Camila Cabello', 'Charlize Theron',
#        'Claire Holt', 'Courtney Cox', 'Dwayne Johnson', 'Elizabeth Olsen',
#        'Ellen Degeneres', 'Henry Cavill', 'Hrithik Roshan',
#        'Hugh Jackman', 'Jessica Alba', 'Kashyap', 'Lisa Kudrow',
#        'Margot Robbie', 'Marmik', 'Natalie Portman', 'Priyanka Chopra',
#        'Robert Downey Jr', 'Roger Federer', 'Tom Cruise',
#        'Vijay Deverakonda', 'Virat Kohli', 'Zac Efron'], dtype='<U17')

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.15, random_state=SEED
)

X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.15, random_state=SEED
)

print('Train:', len(X_train))
print('Val  :', len(X_val))
print('Test :', len(X_test))
# Out:
# Train: 1717
# Val  : 303
# Test : 357

# %%
inp = Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
x = Conv2D(32, 3, activation='relu', padding='same')(inp)
x = MaxPooling2D()(x)
x = Conv2D(64, 3, activation='relu', padding='same')(x)
x = MaxPooling2D()(x)
x = Conv2D(128, 3, activation='relu', padding='same')(x)

# %%
x = MaxPooling2D()(x)
x = Flatten()(x)
x = Dropout(0.3)(x)
x   = Dense(128, activation='relu')(x)
out = Dense(n_class, activation='softmax')(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       3 x = Dropout(0.3)(x)
#       4 x   = Dense(128, activation='relu')(x)
# ----> 5 out = Dense(n_class, activation='softmax')(x)
#
# NameError: name 'n_class' is not defined

# %%
print('Model ready for training!')
# Out:
# array([[[[0.        , 0.05490196, 0.05490196],
#          [0.        , 0.05490196, 0.05490196],
#          [0.        , 0.05490196, 0.05490196],
#          ...,
#          [0.6666667 , 0.6745098 , 0.6627451 ],
#          [0.6666667 , 0.6745098 , 0.6627451 ],
#          [0.6666667 , 0.6745098 , 0.6627451 ]],
#
#         [[0.        , 0.05490196, 0.05490196],
#          [0.        , 0.05490196, 0.05490196],
#          [0.        , 0.05490196, 0.05490196],
#          ...,
#          [0.6666667 , 0.6745098 , 0.6627451 ],
#          [0.6666667 , 0.6745098 , 0.6627451 ],
#          [0.6666667 , 0.6745098 , 0.6627451 ]],
#
#         [[0.        , 0.05490196, 0.05490196],
#          [0.        , 0.05490196, 0.05490196],
#          [0.        , 0.05490196, 0.05490196],
#          ...,
#          [0.6666667 , 0.6745098 , 0.6627451 ],
#          [0.6666667 , 0.6745098 , 0.6627451 ],
#          [0.6666667 , 0.6745098 , 0.6627451 ]],
#
#         ...,
#
#         [[0.14509805, 0.11764706, 0.08627451],
#          [0.15686275, 0.13333334, 0.10196079],
#          [0.16862746, 0.15294118, 0.11764706],
#          ...,
#          [0.7607843 , 0.7529412 , 0.7058824 ],
#          [0.7607843 , 0.7529412 , 0.7058824 ],
#          [0.7607843 , 0.7529412 , 0.7058824 ]],
#
#         [[0.12941177, 0.10196079, 0.07058824],
#          [0.14901961, 0.12156863, 0.09019608],
#          [0.16078432, 0.14509805, 0.10980392],
#          ...,
#          [0.7607843 , 0.7529412 , 0.7058824 ],
#          [0.7607843 , 0.7529412 , 0.7058824 ],
#          [0.7607843 , 0.7529412 , 0.7058824 ]],
#
#         [[0.10980392, 0.08235294, 0.05098039],
#          [0.13333334, 0.10588235, 0.07450981],
#          [0.16078432, 0.13333334, 0.10196079],
#          ...,
#          [0.7607843 , 0.7529412 , 0.7058824 ],
#          [0.7607843 , 0.7529412 , 0.7058824 ],
#          [0.7607843 , 0.7529412 , 0.7058824 ]]],
#
#
#        [[[0.33333334, 0.23137255, 0.24313726],
#          [0.33333334, 0.23137255, 0.24705882],
#          [0.33333334, 0.23529412, 0.2509804 ],
#          ...,
#          [0.36862746, 0.25882354, 0.25490198],
#          [0.38431373, 0.27450982, 0.27058825],
#          [0.36862746, 0.25882354, 0.25490198]],
#
#         [[0.31764707, 0.22352941, 0.23529412],
#          [0.32156864, 0.22745098, 0.23921569],
#          [0.34117648, 0.2509804 , 0.2627451 ],
#          ...,
#          [0.36862746, 0.25882354, 0.25490198],
#          [0.34117648, 0.23137255, 0.22745098],
#          [0.30980393, 0.2       , 0.19607843]],
#
#         [[0.27058825, 0.18431373, 0.19215687],
#          [0.2509804 , 0.16470589, 0.1764706 ],
#          [0.2627451 , 0.18039216, 0.1882353 ],
#          ...,
#          [0.3529412 , 0.24313726, 0.23921569],
#          [0.3372549 , 0.22745098, 0.22352941],
#          [0.31764707, 0.20784314, 0.20392157]],
#
#         ...,
#
#         [[0.16862746, 0.08627451, 0.10588235],
#          [0.16078432, 0.07843138, 0.09803922],
#          [0.16862746, 0.08627451, 0.10588235],
#          ...,
#          [0.30588236, 0.09019608, 0.07843138],
#          [0.34509805, 0.10196079, 0.09803922],
#          [0.34901962, 0.09019608, 0.09411765]],
#
#         [[0.16470589, 0.08235294, 0.10196079],
#          [0.15686275, 0.07450981, 0.09411765],
#          [0.16078432, 0.07843138, 0.09803922],
#          ...,
#          [0.29803923, 0.08235294, 0.07058824],
#          [0.30980393, 0.07058824, 0.06666667],
#          [0.32941177, 0.07843138, 0.07843138]],
#
#         [[0.2       , 0.11764706, 0.13725491],
#          [0.1764706 , 0.09411765, 0.11372549],
#          [0.17254902, 0.09019608, 0.10980392],
#          ...,
#          [0.2901961 , 0.07450981, 0.0627451 ],
#          [0.2901961 , 0.05490196, 0.05098039],
#          [0.3372549 , 0.08627451, 0.08627451]]],
#
#
#        [[[0.04705882, 0.        , 0.01568628],
#          [0.04705882, 0.        , 0.01568628],
#          [0.05490196, 0.00784314, 0.02352941],
#          ...,
#          [0.10196079, 0.05882353, 0.05098039],
#          [0.08235294, 0.03921569, 0.03137255],
#          [0.04313726, 0.00784314, 0.00392157]],
#
#         [[0.04705882, 0.        , 0.01176471],
#          [0.04705882, 0.        , 0.01176471],
#          [0.05098039, 0.00392157, 0.01568628],
#          ...,
#          [0.10196079, 0.05882353, 0.05098039],
#          [0.09803922, 0.05882353, 0.04705882],
#          [0.07450981, 0.03921569, 0.02352941]],
#
#         [[0.04705882, 0.        , 0.00784314],
#          [0.04705882, 0.        , 0.00784314],
#          [0.05098039, 0.00392157, 0.01176471],
#          ...,
#          [0.09803922, 0.05098039, 0.04705882],
#          [0.09803922, 0.05882353, 0.04313726],
#          [0.09019608, 0.05882353, 0.03529412]],
#
#         ...,
#
#         [[0.62352943, 0.5529412 , 0.44313726],
#          [0.78039217, 0.7254902 , 0.6156863 ],
#          [0.70980394, 0.6431373 , 0.5254902 ],
#          ...,
#          [0.08627451, 0.01960784, 0.00392157],
#          [0.18431373, 0.09803922, 0.05098039],
#          [0.25490198, 0.16078432, 0.10588235]],
#
#         [[0.78431374, 0.7372549 , 0.7176471 ],
#          [1.        , 0.972549  , 0.9490196 ],
#          [0.99215686, 0.9490196 , 0.9098039 ],
#          ...,
#          [0.05098039, 0.        , 0.        ],
#          [0.10980392, 0.03529412, 0.00784314],
#          [0.19215687, 0.11372549, 0.05490196]],
#
#         [[0.8117647 , 0.78431374, 0.81960785],
#          [0.8784314 , 0.84313726, 0.87058824],
#          [0.8862745 , 0.84705883, 0.85882354],
#          ...,
#          [0.0627451 , 0.00784314, 0.        ],
#          [0.07058824, 0.00392157, 0.        ],
#          [0.12941177, 0.05490196, 0.00392157]]],
#
#
#        ...,
#
#
#        [[[0.18431373, 0.17254902, 0.15294118],
#          [0.1882353 , 0.1764706 , 0.16078432],
#          [0.19607843, 0.18039216, 0.16862746],
#          ...,
#          [0.12941177, 0.12156863, 0.14117648],
#          [0.2       , 0.19215687, 0.21176471],
#          [0.29411766, 0.28627452, 0.30588236]],
#
#         [[0.17254902, 0.15686275, 0.14117648],
#          [0.18431373, 0.16470589, 0.15294118],
#          [0.19607843, 0.18039216, 0.16862746],
#          ...,
#          [0.12156863, 0.11372549, 0.12941177],
#          [0.12941177, 0.12156863, 0.14117648],
#          [0.19607843, 0.1882353 , 0.20392157]],
#
#         [[0.16470589, 0.14901961, 0.13725491],
#          [0.18039216, 0.16470589, 0.15686275],
#          [0.2       , 0.18431373, 0.17254902],
#          ...,
#          [0.20784314, 0.20392157, 0.21176471],
#          [0.11764706, 0.10980392, 0.12156863],
#          [0.09411765, 0.08627451, 0.09803922]],
#
#         ...,
#
#         [[0.7176471 , 0.8392157 , 0.89411765],
#          [0.7176471 , 0.8392157 , 0.89411765],
#          [0.7254902 , 0.84313726, 0.9019608 ],
#          ...,
#          [0.7411765 , 0.5921569 , 0.56078434],
#          [0.7411765 , 0.5921569 , 0.56078434],
#          [0.7411765 , 0.5921569 , 0.56078434]],
#
#         [[0.7019608 , 0.84313726, 0.88235295],
#          [0.7058824 , 0.84705883, 0.8862745 ],
#          [0.7137255 , 0.84705883, 0.89411765],
#          ...,
#          [0.7294118 , 0.5764706 , 0.54901963],
#          [0.7411765 , 0.5882353 , 0.57254905],
#          [0.7529412 , 0.59607846, 0.58431375]],
#
#         [[0.69411767, 0.84313726, 0.8784314 ],
#          [0.69803923, 0.84705883, 0.88235295],
#          [0.7058824 , 0.8509804 , 0.8862745 ],
#          ...,
#          [0.7058824 , 0.5568628 , 0.53333336],
#          [0.7411765 , 0.5803922 , 0.5764706 ],
#          [0.76862746, 0.6039216 , 0.60784316]]],
#
#
#        [[[0.21960784, 0.1882353 , 0.1764706 ],
#          [0.22352941, 0.19215687, 0.18039216],
#          [0.2       , 0.16862746, 0.15686275],
#          ...,
#          [0.3019608 , 0.23137255, 0.14117648],
#          [0.34901962, 0.28627452, 0.18431373],
#          [0.42745098, 0.3647059 , 0.2627451 ]],
#
#         [[0.18431373, 0.15294118, 0.14117648],
#          [0.20392157, 0.17254902, 0.16078432],
#          [0.19215687, 0.16078432, 0.14901961],
#          ...,
#          [0.3254902 , 0.25882354, 0.17254902],
#          [0.34509805, 0.28235295, 0.1882353 ],
#          [0.30588236, 0.25490198, 0.14901961]],
#
#         [[0.16862746, 0.13725491, 0.1254902 ],
#          [0.19607843, 0.16470589, 0.15294118],
#          [0.1882353 , 0.15686275, 0.14509805],
#          ...,
#          [0.5019608 , 0.44313726, 0.3647059 ],
#          [0.49019608, 0.4392157 , 0.3529412 ],
#          [0.34509805, 0.3019608 , 0.20784314]],
#
#         ...,
#
#         [[0.76862746, 0.57254905, 0.5058824 ],
#          [0.74509805, 0.5568628 , 0.4862745 ],
#          [0.7294118 , 0.54509807, 0.4627451 ],
#          ...,
#          [0.6901961 , 0.7019608 , 0.7372549 ],
#          [0.7058824 , 0.7176471 , 0.7529412 ],
#          [0.7254902 , 0.7372549 , 0.77254903]],
#
#         [[0.7647059 , 0.5764706 , 0.50980395],
#          [0.77254903, 0.5803922 , 0.50980395],
#          [0.7647059 , 0.5686275 , 0.49411765],
#          ...,
#          [0.6039216 , 0.6156863 , 0.6509804 ],
#          [0.6156863 , 0.627451  , 0.6627451 ],
#          [0.6313726 , 0.6431373 , 0.6784314 ]],
#
#         [[0.74509805, 0.5529412 , 0.4862745 ],
#          [0.76862746, 0.5764706 , 0.5058824 ],
#          [0.77254903, 0.5686275 , 0.49019608],
#          ...,
#          [0.5372549 , 0.54901963, 0.58431375],
#          [0.54901963, 0.56078434, 0.59607846],
#          [0.5647059 , 0.5764706 , 0.6117647 ]]],
#
#
#        [[[0.27058825, 0.20392157, 0.1254902 ],
#          [0.26666668, 0.2       , 0.1254902 ],
#          [0.25490198, 0.1882353 , 0.12156863],
#          ...,
#          [0.24313726, 0.18039216, 0.13725491],
#          [0.27450982, 0.20784314, 0.17254902],
#          [0.29803923, 0.23137255, 0.19607843]],
#
#         [[0.25882354, 0.19215687, 0.11372549],
#          [0.2627451 , 0.19607843, 0.12156863],
#          [0.2627451 , 0.19607843, 0.12156863],
#          ...,
#          [0.22745098, 0.16470589, 0.11372549],
#          [0.25882354, 0.19607843, 0.15294118],
#          [0.28627452, 0.22352941, 0.18039216]],
#
#         [[0.21176471, 0.14509805, 0.06666667],
#          [0.22745098, 0.16078432, 0.08235294],
#          [0.24313726, 0.1764706 , 0.09803922],
#          ...,
#          [0.21176471, 0.14901961, 0.09019608],
#          [0.22745098, 0.16862746, 0.10980392],
#          [0.25882354, 0.20784314, 0.14901961]],
#
#         ...,
#
#         [[0.4117647 , 0.27450982, 0.19215687],
#          [0.42745098, 0.29411766, 0.2       ],
#          [0.40784314, 0.27450982, 0.16470589],
#          ...,
#          [0.22352941, 0.23137255, 0.28235295],
#          [0.21568628, 0.21960784, 0.28627452],
#          [0.2       , 0.20392157, 0.28235295]],
#
#         [[0.3882353 , 0.25882354, 0.16862746],
#          [0.42745098, 0.29411766, 0.19607843],
#          [0.42745098, 0.29803923, 0.17254902],
#          ...,
#          [0.21960784, 0.23137255, 0.2901961 ],
#          [0.21176471, 0.21960784, 0.29803923],
#          [0.20784314, 0.21568628, 0.29411766]],
#
#         [[0.3529412 , 0.23137255, 0.12941177],
#          [0.40392157, 0.2784314 , 0.16862746],
#          [0.42352942, 0.2901961 , 0.16862746],
#          ...,
#          [0.21568628, 0.22745098, 0.29411766],
#          [0.20784314, 0.21960784, 0.3019608 ],
#          [0.20784314, 0.21568628, 0.30588236]]]],
#       shape=(2377, 128, 128, 3), dtype=float32)

# %%
model = Model(inp, out)
model.compile(
    optimizer = 'adam',
    loss      = 'sparse_categorical_crossentropy',
    metrics   = ['accuracy']
)

model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     4,194,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 29)             │         3,741 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,291,421 (16.37 MB)
#  Trainable params: 4,291,421 (16.37 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# يوقف التدريب لما val_accuracy تتوقف عن التحسن لـ 5 epochs
early_stop = EarlyStopping(
    monitor  = 'val_accuracy',
    patience = 5,
    restore_best_weights = True,  # يرجع لأفضل نقطة تلقائياً
    verbose  = 1
)

# يخفّض الـ learning rate لما val_accuracy تتوقف لـ 3 epochs
reduce_lr = ReduceLROnPlateau(
    monitor  = 'val_accuracy',
    factor   = 0.5,   # يقسّم الـ learning rate على 2
    patience = 3,
    min_lr   = 1e-6,
    verbose  = 1
)

history = model.fit(
    X_train, y_train,
    epochs          = 100,        # نحط كبير لأن early_stop يوقف تلقائياً
    batch_size      = 8,
    validation_data = (X_val, y_val),
    callbacks       = [early_stop, reduce_lr]
)
# Out:
# Epoch 1/80
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 27s 125ms/step
ification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step
#
# Report:
#                     precision    recall  f1-score   support
#
#        Alia Bhatt       0.00      0.00      0.00         2
#  Amitabh Bachchan       0.87      0.93      0.90        14
#      Andy Samberg       1.00      0.70      0.82        10
#    Anushka Sharma       0.50      0.40      0.44        15
#     Billie Eilish       0.41      0.64      0.50        14
#         Brad Pitt       0.94      0.68      0.79        22
#    Camila Cabello       0.88      0.58      0.70        12
#   Charlize Theron       0.82      0.70      0.76        20
#       Claire Holt       0.57      0.50      0.53         8
#      Courtney Cox       0.22      0.57      0.32         7
#    Dwayne Johnson       1.00      0.40      0.57        10
#   Elizabeth Olsen       0.67      0.57      0.62         7
#   Ellen Degeneres       0.80      0.40      0.53        10
#      Henry Cavill       0.56      0.59      0.57        17
#    Hrithik Roshan       1.00      0.50      0.67        16
#      Hugh Jackman       0.72      0.72      0.72        18
#      Jessica Alba       1.00      0.36      0.53        14
#           Kashyap       0.75      0.50      0.60         6
#       Lisa Kudrow       0.78      0.54      0.64        13
#     Margot Robbie       0.46      0.67      0.55         9
#            Marmik       0.00      0.00      0.00         4
#   Natalie Portman       0.47      0.77      0.59        22
#   Priyanka Chopra       0.57      0.86      0.69        14
#  Robert Downey Jr       0.52      0.75      0.62        16
#     Roger Federer       0.67      0.88      0.76        16
#        Tom Cruise       1.00      0.29      0.44         7
# Vijay Deverakonda       0.76      0.94      0.84        17
#       Virat Kohli       0.86      1.00      0.92         6
#         Zac Efron       0.77      0.91      0.83        11
#
#          accuracy                           0.65       357
#         macro avg       0.67      0.60      0.60       357
#      weighted avg       0.71      0.65      0.65       357
# c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
feature_extractor = Model(inputs=model.input, outputs=model.layers[-2].output)
feature_extractor
# Out:
# <Functional name=functional_2, built=True>

# %%
import pandas as pd

df = pd.read_excel(r'D:/Dev/datascience-course/final_project2/Students_Images/Students.xlsx')

student_features = {}

for _, row in df.iterrows():
    name     = str(row['Name'])
    img_path = str(row['Image Path'])

    if not os.path.exists(img_path):
        print(f'Image not found: {img_path}')
        continue

    img = load_img(img_path)
    img = np.expand_dims(img, axis=0)

    features = feature_extractor.predict(img, verbose=0).flatten()

    if name in student_features:
        student_features[name] = (student_features[name] + features) / 2
    else:
        student_features[name] = features

class_names = list(student_features.keys())
class_names
# Out:
# ['Malak', 'malak', 'ali']

# %%
import json

model.save('face_model.keras')

embeddings = {name: feat.tolist() for name, feat in student_features.items()}
with open('student_features.json', 'w') as f:
    json.dump(embeddings, f)

# %%
# !pip install mediapipe --user
# Out:
# Requirement already satisfied: mediapipe in C:\Users\con027931\AppData\Roaming\Python\Python313\site-packages (0.10.33)
# Requirement already satisfied: absl-py~=2.3 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from mediapipe) (2.3.1)
# Requirement already satisfied: numpy in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from mediapipe) (2.3.3)
# Requirement already satisfied: sounddevice~=0.5 in C:\Users\con027931\AppData\Roaming\Python\Python313\site-packages (from mediapipe) (0.5.5)
# Requirement already satisfied: flatbuffers~=25.9 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from mediapipe) (25.12.19)
# Requirement already satisfied: opencv-contrib-python in C:\Users\con027931\AppData\Roaming\Python\Python313\site-packages (from mediapipe) (4.13.0.92)
# Requirement already satisfied: matplotlib in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from mediapipe) (3.10.7)
# Requirement already satisfied: cffi in C:\Users\con027931\AppData\Roaming\Python\Python313\site-packages (from sounddevice~=0.5->mediapipe) (2.0.0)
# Requirement already satisfied: pycparser in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from cffi->sounddevice~=0.5->mediapipe) (3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from matplotlib->mediapipe) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from matplotlib->mediapipe) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from matplotlib->mediapipe) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from matplotlib->mediapipe) (25.0)
# Requirement already satisfied: pillow>=8 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from matplotlib->mediapipe) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\con027931\AppData\Local\miniconda3\envs\env_studying\Lib\site-packages (from matplotlib->mediapipe) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\con027931\AppData\Roaming\Python\Python313\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\con027931\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)

# %%
import cv2
import numpy as np

def detect_drowsiness(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    eye_cascade  = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')
    
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    
    if len(faces) == 0:
        return 'No Face'
    
    for (x, y, w, h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        eyes     = eye_cascade.detectMultiScale(roi_gray)
        
        if len(eyes) >= 2:
            return 'Active'
        else:
            return 'Sleepy'
    
    return 'No Face'

# %%
import json

model.save("face_model.keras")

embeddings = {name: feat.tolist() for name, feat in student_features.items()}
with open("student_features.json", "w") as f:
    json.dump(embeddings, f)
